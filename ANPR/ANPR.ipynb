# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image=cv2.imread('Images/car_10.jpg')
image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-3-4cc7d94fdf93> in <module>
#       1 image=cv2.imread('Images/car_10.jpg')
# ----> 2 image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
#
# error: OpenCV(4.5.3) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-sn_xpupm\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
plt.imshow(image)

# %%
def plot_image(image,title=""):
    plt.figure(figsize=[10,10])
    plt.title(title)
    plt.imshow(image,cmap='gray')

# %%
plot_image(image,"Car Image")

# %%
gray_image.shape
# Out:
# (280, 468)

# %%
gray_image=cv2.imread('Images/car_10.jpg',0)

# %%
plot_image(gray_image)

# %%
plt.imshow(gray_image,cmap='gray')

# %%
#plt.imshow(image,cmap='gray')

# %%
blur_image=cv2.GaussianBlur(gray_image,(5,5),0)

# %%
plot_image(blur_image)

# %%
edged_image=cv2.Canny(blur_image,120,170)

# %%
plot_image(edged_image)
